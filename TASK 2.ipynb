# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %% [markdown]
# objective of this notebook is:
#
# 1)Analysis of the features.
#
# 2)Finding any relations or trends considering multiple features.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv("C:\\Users\\carol\\OneDrive\\Documents\\progidy\\titanic\\train.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# The Age, Cabin and Embarked have null values.

# %%
fig, ax = plt.subplots(figsize=(8,8))
data['Survived'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax, shadow=True)
ax.set_title('Survived')
ax.set_ylabel('')

plt.show()

# %% [markdown]
# It is evident that not many passengers survived the accident.
#
# Out of 891 passengers in training set, only around 350 survived i.e Only 38.4% of the total training set survived the crash.

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

data[['Sex', 'Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')

sns.countplot(x='Sex', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')

plt.show()

# %% [markdown]
# The number of men on the ship is lot more than the number of women. Still the number of women saved is almost twice the number of males saved. The survival rates for a women on the ship is around 75% while that for men in around 18-19%.

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_d28d2_row0_col0, #T_d28d2_row1_col1, #T_d28d2_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_d28d2_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_d28d2_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_d28d2_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_d28d2_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_d28d2_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_d28d2_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_d28d2_row3_col0, #T_d28d2_row3_col1, #T_d28d2_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d28d2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_d28d2_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d28d2_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_d28d2_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d28d2_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d28d2_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_d28d2_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_d28d2_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_d28d2_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d28d2_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_d28d2_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_d28d2_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_d28d2_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d28d2_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_d28d2_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_d28d2_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_d28d2_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_d28d2_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_d28d2_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_d28d2_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

data['Pclass'].value_counts().plot.bar(color=['#CD7F32', '#FFD700', '#D3D3D3'], ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')

sns.countplot(x='Pclass', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Pclass: Survived vs Dead')

plt.show()

# %% [markdown]
# we can clearly see that Passenegers Of Pclass 1 were given a very high priority while rescue. Even though the the number of Passengers in Pclass 3 were a lot higher, still the number of survival from them is very low, somewhere around 25%.

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
print(data.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data['Initial'] = data['Name'].str.extract('([A-Za-z]+)\.', expand=False)
data['Initial'].replace(
    ['Mlle', 'Mme', 'Ms', 'Dr', 'Major', 'Lady', 'Countess', 'Jonkheer', 'Col', 'Rev', 'Capt', 'Sir', 'Don'],
    ['Miss', 'Miss', 'Miss', 'Mr', 'Mr', 'Mrs', 'Mrs', 'Other', 'Other', 'Other', 'Mr', 'Mr', 'Mr'],
    inplace=True
)

print(data['Initial'].value_counts())
# Out:
# Initial
# Mr        529
# Miss      186
# Mrs       127
# Master     40
# Other       9
# Name: count, dtype: int64

# %%
data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %% [markdown]
# Assigning the NaN Values with the values of the mean ages

# %%
data.Age.isnull().any()
# Out:
# False

# %% [markdown]
# no null values left

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black', color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %% [markdown]
# 1)The Toddlers(age<5) were saved in large numbers(The Women and Child First Policy).
#
# 2)The oldest Passenger was saved(80 years).
#
# 3)Maximum number of deaths were in the age group of 30-40.

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Initial          0
# dtype: int64

# %%
#changing the data types for the columns Survived, PClass, Sex, Age and Embarked 
data['Survived']=data['Survived'].astype('category')
data['Pclass']=data['Pclass'].astype('category')
data['Sex']=data['Sex'].astype('category')
data['Age']=data['Age'].astype('int')
data['Embarked']=data['Embarked'].astype('category')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          891 non-null    int32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    category
#  12  Initial      891 non-null    object
# dtypes: category(4), float64(1), int32(1), int64(3), object(4)
# memory usage: 63.3+ KB

# %%
data.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.826038    0.523008    0.381594   32.204208
# std     257.353842   13.290448    1.102743    0.806057   49.693429
# min       1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     223.500000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000   30.000000    0.000000    0.000000   14.454200
# 75%     668.500000   36.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %%
#Distribution of Embarked
plt.figure(figsize=(8, 6))
sns.countplot(x = 'Embarked', data=data, palette = 'Set1')
plt.title('Embarked Distribution')
plt.xlabel('Port of Embarkation')
plt.ylabel('Count') 
plt.show()

# %%
correlation = data['Age'].corr(data['Fare'])
print("Correlation coefficient between Age and Fare:", correlation)
# Out:
# Correlation coefficient between Age and Fare: 0.08923511465303959

# %%
#box plot for identifying outliers for the column Age
plt.figure(figsize=(8, 6))
sns.boxplot(x='Age', data=data)
plt.xlabel('Age')
plt.title('Box Plot: Distribution of Age')
plt.grid(True)
plt.show()

# %%
#count plot for SibSp column
sns.countplot(x='SibSp', data=data)
plt.show()

# %%
#count plot for Parch column
sns.countplot(x='Parch', data=data, palette = 'Set1')
plt.show()

# %%
#distribution of passengers based on family size to know who survived. 
data['FamilySize'] = data['SibSp'] + data['Parch'] + 1
plt.figure(figsize=(10, 6))
sns.countplot(x='FamilySize', hue='Survived', data=data, palette='Set1')
plt.title('Survival Count by Family Size')
plt.xlabel('Family Size')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()
